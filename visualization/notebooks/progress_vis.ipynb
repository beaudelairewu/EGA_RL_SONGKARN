# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
path = "/Users/noppa/Documents/AI_logs/multi_train/17.04.24-1115/infoLogs/progress.csv"

# %%
data = pd.read_csv(path)

# %%
df
# Out:
#    rollout/ep_len_mean  time/fps  time/total_timesteps  time/time_elapsed  \
# 0                 7.32         1                 64944               3372
# 1                 9.40         1                 71088               6779
# 2                10.56         1                 77232              10185
# 3                10.05         1                 83376              13596
# 4                 6.98         1                 89520              17011
# 5                11.05         1                 95664              20431
# 6                 8.23         1                101808              23848
# 7                11.01         1                107952              27269
# 8                 7.26         1                114096              30691
#
#    rollout/ep_rew_mean  time/iterations  train/learning_rate    train/loss  \
# 0            46.909657                1                  NaN           NaN
# 1            74.651344                2               0.0003   7384.489258
# ...

# %%
eject = ["time/fps", "time/total_timesteps", "time/time_elapsed", "time/iterations"]
columns_to_plot = set(df.columns) ^ set(eject)
print(columns_to_plot)
n_cols = 3
n_rows = math.ceil(len(columns_to_plot)/n_cols)

print(n_rows)
fig, axes = plt.subplots(nrows=n_rows, ncols=n_cols, figsize=(15, 18))
axes = axes.flatten()  

for ax, col in zip(axes, columns_to_plot):
    ax.plot(data['time/total_timesteps'], data[col])
    ax.set_title(col.replace('/', ' ').title())
    ax.set_xlabel('steps')
    ax.set_ylabel(col.replace('/', ' ').title())

# Adjust the spacing between subplots
plt.subplots_adjust(hspace=0.5, wspace=0.5)

# Display the plots
plt.show()
# Out:
# {'train/learning_rate', 'train/n_updates', 'train/clip_fraction', 'train/entropy_loss', 'rollout/ep_rew_mean', 'train/value_loss', 'train/policy_gradient_loss', 'train/approx_kl', 'train/loss', 'train/clip_range', 'rollout/ep_len_mean', 'train/explained_variance', 'train/std'}
# 5
